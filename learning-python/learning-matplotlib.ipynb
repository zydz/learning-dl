# %% [markdown]
# Learning Matplotlib
# ---
# This Notebook is for learning labrary matplotlib
#
# Matplotlib is a Python 2D plotting library which produces publication-quality figures in a variety of hardcopy formats and interactive environments across
# platforms.
#
#
# ![](images/matplotlib-1.png)

# %% [markdown]
# ## Plot Anatomy & Workflow
# ### Plot Anatomy
# __TODO__

# %% [markdown]
# #### Workflow
# * 1 Prepare data
# * 2 Create plot
# * 3 Plot
# * 4 Customize plot
# * 5 Save plot
# * 6 Show plot

# %%
import matplotlib.pyplot as plt
# Step 1
x = [1,2,3,4]
y = [10,20,25,30]


fig = plt.figure() #Step 2

ax = fig.add_subplot(111) #Step 3

# Step 4
ax.plot(x, y, color='lightblue', linewidth=3) 
ax.scatter([2,4,6],
               [5,15,25],
               color='darkgreen',
               marker='^')
ax.set_xlim(1, 6.5)

# Step 5
plt.savefig('foo.png')

#Step 6
plt.show()

# %% [markdown]
# ### 1. Prepare the Data
# #### Data

# %%
import numpy as np
x = np.linspace(0, 10, 100)
y = np.cos(x)
z = np.sin(x)

# %% [markdown]
# #### Data or Images

# %%
data = 2 * np.random.random((10,10))
data2 = 3 * np.random.random((10,10))

Y,X = np.mgrid[-3:3:100j, -3:3:100j]

U = -1 - X**2 +Y

V = 1 + X - Y**2

from matplotlib.cbook import get_sample_data

img = np.load(get_sample_data('axes_grid/bivariate_normal.npy'))

# %% [markdown]
# ### 2.Create Plot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Figure

# %%
fig = plt.figure()
fig2= plt.figure(figsize=plt.figaspect(2.0))

# %% [markdown]
# #### Axes
# All plotting is done with respect to an Axes. In most cases, a subplot will fit your needs. A subplot is an axes on a grid system.

# %%
fig.add_axes()
ax1 = fig.add_subplot(221)    # row-col-num
ax3 = fig.add_subplot(212)
fig3, axes = plt.subplots(nrows=2, ncols=2)
fig4, axes2 = plt.subplots(ncols=3)

# %% [markdown]
# ### 3. Plotting Routines
# #### Data

# %%
fig, ax = plt.subplots()

'''
Draw points with lines or markers connecting them Draw unconnected points, scaled or colored
Plot vertical rectangles (constant width)
Plot horiontal rectangles (constant height)
Draw a horizontal line across axes Draw a vertical line across axes Draw filled polygons
Fill between y-values and 0
'''
lines = ax.plot(x,y)
ax.scatter(x,y)
axes[0,0].bar([1,2,3],[3,4,5])
axes[1,0].barh([0.5,1,2.5],[0,1,2])
axes[1,1].axhline(0.45)
axes[0,1].axvline(0.65)
ax.fill(x, y, color='blue')
ax.fill_between(x,y, color='yellow')

# %% [markdown]
# #### Vector Fields

# %%
# Add an arrow to the axes
axes[0,1].arrow(0,0,0.5,0.5)

# Plot a 2D field of arrows
axes[1,1].quiver(y,z)

# Plot a 2D field of arrows
axes[0,1].streamplot(X,Y,U,V)

# %% [markdown]
# #### Data Distributions

# %%
# Plot a histogram
ax1.hist(y)

# Make a box and whisker plot
ax3.boxplot(y)

# Make a violin plot
ax3.violinplot(z)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x10f601a58>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x10f6017f0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x10f601e48>,
#  'cbars': <matplotlib.collections.LineCollection at 0x10f7417b8>}

# %% [markdown]
# #### Data Images

# %%
fig, ax = plt.subplots()

# Colormapped or RGB arrays
im = ax.imshow(img,
               cmap='gist_earth',
                interpolation='nearest',
                vmin=-2,
                vmax=2)

# %%
# Pseudocolor plot of 2D array
axes2[0].pcolor(data2)

# Pseudocolor plot of 2D array
axes2[2].pclolormesh(data)

# Plot contours
CS = plt.contour(Y,X,U)

# Plot filied contours
axes2[2].contourf(data1)

#Label a contour plot
axes2[2] = ax.clabel(CS)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-7b8d05e986cb> in <module>
#       3
#       4 # Pseudocolor plot of 2D array
# ----> 5 axes2[2].pclolormesh(data)
#       6
#       7 # Plot contours
#
# AttributeError: 'AxesSubplot' object has no attribute 'pclolormesh'

# %% [markdown]
# ### Customize plot

# %% [markdown]
# #### Colors, Color Bars, Color Maps

# %%
plt.plot(x, x, x, x**2, x, x**3)
# Out:
# [<matplotlib.lines.Line2D at 0x10eb40a58>,
#  <matplotlib.lines.Line2D at 0x10eb40dd8>,
#  <matplotlib.lines.Line2D at 0x10eb404a8>]

# %%
ax.plot(x, y, alpha = 0.4)
ax.plot(x, y, c='k')

# %%
fig.colorbar(im, orientation='horizontal')
im = ax.imshow(img,cmp='seismic')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-f8630673032d> in <module>
#       1 fig.colorbar(im, orientation='horizontal')
# ----> 2 im = ax.imshow(img,cmp='seismic')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5656         im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    5657                               filternorm=filternorm, filterrad=filterrad,
# -> 5658                               resample=resample, **kwargs)
#    5659
#    5660         im.set_data(X)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/image.py in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, **kwargs)
#     855             filterrad=filterrad,
#     856             resample=resample,
# --> 857             **kwargs
#     858         )
#     859
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/image.py in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, **kwargs)
#     218         self._imcache = None
#     219
# --> 220         self.update(kwargs)
#     221
#     222     def __getstate__(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     955
#     956         with cbook._setattr_cm(self, eventson=False):
# --> 957             ret = [_update_property(self, k, v) for k, v in props.items()]
#     958
#     959         if len(ret):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     951                 if not callable(func):
#     952                     raise AttributeError('{!r} object has no property {!r}'
# --> 953                                          .format(type(self).__name__, k))
#     954                 return func(v)
#     955
#
# AttributeError: 'AxesImage' object has no property 'cmp'

# %% [markdown]
# #### Markers

# %%
fig, az = plt.subplots()
ax.scatter(x,y,marker='.')
ax.plot(x, y, marker='o')

# %% [markdown]
# #### Linestyles

# %%
plt.plot(x, y, linewidth=4.0)
plt.plot(x, y, ls='solid')
plt.plot(x, y, ls='--')
plt.plot(x, y, '--', x**2, y**2, '-.')
plt.setp(lines, color='r', linewidth=4.0)

# %% [markdown]
# #### Text & Annotations

# %%
ax.text(1, -2.1, 'Example Graph',style='italic')
ax.annotate('Sine', xy=(8,0),
           xycoords='data',
            xytext=(10.5,0),
            textcoords='data',
            arrowprops=dict(arrowstyle="->",
            connectionstyle="arc3"),
           )

# %% [markdown]
# #### Mathtext

# %%
plt.title(r'$sigma_i=15$', fontsize=20)

# %% [markdown]
# ### Limits, Legends & Layouts
# #### Limits & Autoscaling

# %%
# Add padding to a plot
ax.margins(x=0.0, y=0.1)

# Set the aspect ratio of the plot to 1 
ax.axis('equal')

# Set limits for x-and y-axis
ax.set(xlim=[0, 10.5],ylim=[-1.5,1.5])

# Set limits for x-axis
ax.set_xlim(0, 10.5)

# %% [markdown]
# #### Legends

# %%
# Set a title and x-and y-axis labels
ax.set(title='An Example Axes',
       ylabel='Y-Axis',
       xlabel='X-Axis'
      )

# No overlapping plot elements
ax.legend(loc='best')

# %% [markdown]
# #### Ticks

# %%
# Manually set x-ticks
ax.xaxis.set(ticks=range(1,5),
             ticklabels=[3,100,-12,'foo']
            )

# Make y-ticks longer and go in and out
ax.tick_params(axis='y',
               direction='inout',
               length=10
              )

# %% [markdown]
# #### Subplot Spacing

# %%
# Adjust the spacing between subplots
fig3.subplots_adjust(wspace=0.5,
                     hspace=0.3,
                     left=0.125,
                     right=0.9,
                     top=0.9,
                     bottom=0.1
)

# Fit subplot(s) in to the figure area
fig.tight_layout()

# %% [markdown]
# #### Axis Spines

# %%
# Make the top axis line for a plot invisible
ax1.spines['top'].set_visible(False)

# Move the bottom axis line outward
ax1.spines['bottom'].set_position(('outward',10))

# %% [markdown]
# ### 5 Save Plot

# %% [markdown]
# #### Save Figures

# %%
plt.savefig('foo.png')

# %% [markdown]
# #### Save transparent figures

# %%
plt.savefig('foo.png', transparent=True)

# %% [markdown]
# ### 6 Show Plot

# %%
plt.show()

# %% [markdown]
# ## Close & Clear

# %%
# Clear an axis
plt.cla()

# Clear the entire figure
plt.clf()

# Close a window
plt.close()
